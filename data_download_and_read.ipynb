# %% [markdown]
# # Final Project - What is the Best Indicator of Success on the PGA Tour?
# Max Guryan
# DS 2023
# ## Notebook 1: Data Download and Read
# Before we beign, it is important to set up a virtual environment with the necessary packages. This can be done by running the following command in your terminal. Make sure that your working directory is set to `final_project` before running this command. (Copy and paste the command as a single line in your terminal.)
#
# ```bash
# python -m venv .venv && source .venv/bin/activate && pip install -r requirements.txt
# ```
#
# Once this environment is set up, make sure you select the `.venv` kernel in Jupyter Notebook to ensure that the correct packages are being used.

# %% [markdown]
# ### Import Packages
# Run the cell below to import the necessary packages for this notebook.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Data Download
# The data used in this analysis comes from the PGA TOUR's website. Unfortunately, the data is only available for download as individual CSV files for a given stat in a given year. I have written a series of python scripts to download and merge these files into a master dataset. The scripts can be found in the `final_project/src` directory. However, to save time, I have already run these scripts and saved the final merged dataset as `master_player_seasons.csv` in the `final_project/data/processed` directory.
#
# **Note:** The three scripts used to download and merege the dataset are from my DS2022 final project. They have been modified to fit the needs of this analysis.

# %% [markdown]
# The external link to the PGA TOUR's stats page is: [PGA TOUR Stats](https://www.pgatour.com/stats)
#
# The API endpoint used to download the data is:
# ```
#     "https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId={stat_id}&year={year}"
# ```
# `stat_id` indicates which stat is being downloaded, and `year` indicates which year the data is from.

# %% [markdown]
# Here is a dictionary of each stat and its corresponding `stat_id`:
# ```python
# STAT_IDS = {
#     "sg_total": "02675", # Strokes Gained: Total
#     "sg_ott": "02567", # Strokes Gained: Off the Tee
#     "sg_app": "02568", # Strokes Gained: Approaching the Green
#     "sg_arg": "02569", # Strokes Gained: Around the Green
#     "sg_putt": "02564", # Strokes Gained: Putting
#
#     # Traditional stats
#     "driving_distance": "101",
#     "driving_accuracy": "102",
#     "greens_in_regulation": "103",
#     "scoring_average": "120",
#
#     # Success metrics
#     "money_earned": "109",   # Money Leaders
#     "fedex_rank": "02671",   # FedEx / points-style ranking you picked
# }
# ```

# %% [markdown]
# ### How the PGA TOUR Collects the Data:
# The PGA TOUR collects its data through automated tracking and manual entry of every shot taken by every golfer in every tournament during a given season. This data is then used to calculate various advanced statistics, such as strokes gained metrics, greens in regulation, and scoring average. Additionally, advanced shot tracking technology, such as ShotLink, is used to collect data on shot distances, accuracy, proximity, and other factors that contribute to a golfer's performance on the course. Finally, FedEx ranking and money earned data is collected based on a golfer's placement in tournaments throughout the season. All this data is compiled and made publicly available to inspect and download through the PGA TOUR website.

# %% [markdown]
# ### --- IGNORE BELOW ---
# Do not run the cells below. They are only for reference.

# %%
# %run src/download_stats.py
# Out:
# Downloading sg_total (02675) for 2007
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02675&year=2007
#   Saved to data/raw/sg_total_2007.csv
#
# Downloading sg_ott (02567) for 2007
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02567&year=2007
#   Saved to data/raw/sg_ott_2007.csv
#
# Downloading sg_app (02568) for 2007
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02568&year=2007
#   Saved to data/raw/sg_app_2007.csv
#
# Downloading sg_arg (02569) for 2007
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02569&year=2007
#   Saved to data/raw/sg_arg_2007.csv
#
# Downloading sg_putt (02564) for 2007
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02564&year=2007
#   Saved to data/raw/sg_putt_2007.csv
#
# Downloading driving_distance (101) for 2007
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=101&year=2007
#   Saved to data/raw/driving_distance_2007.csv
#
# Downloading driving_accuracy (102) for 2007
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=102&year=2007
#   Saved to data/raw/driving_accuracy_2007.csv
#
# Downloading greens_in_regulation (103) for 2007
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=103&year=2007
#   Saved to data/raw/greens_in_regulation_2007.csv
#
# Downloading scoring_average (120) for 2007
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=120&year=2007
#   Saved to data/raw/scoring_average_2007.csv
#
# Downloading money_earned (109) for 2007
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=109&year=2007
#   Saved to data/raw/money_earned_2007.csv
#
# Downloading fedex_rank (02671) for 2007
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02671&year=2007
#   Saved to data/raw/fedex_rank_2007.csv
#
# Downloading sg_total (02675) for 2008
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02675&year=2008
#   Saved to data/raw/sg_total_2008.csv
#
# Downloading sg_ott (02567) for 2008
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02567&year=2008
#   Saved to data/raw/sg_ott_2008.csv
#
# Downloading sg_app (02568) for 2008
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02568&year=2008
#   Saved to data/raw/sg_app_2008.csv
#
# Downloading sg_arg (02569) for 2008
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02569&year=2008
#   Saved to data/raw/sg_arg_2008.csv
#
# Downloading sg_putt (02564) for 2008
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02564&year=2008
#   Saved to data/raw/sg_putt_2008.csv
#
# Downloading driving_distance (101) for 2008
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=101&year=2008
#   Saved to data/raw/driving_distance_2008.csv
#
# Downloading driving_accuracy (102) for 2008
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=102&year=2008
#   Saved to data/raw/driving_accuracy_2008.csv
#
# Downloading greens_in_regulation (103) for 2008
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=103&year=2008
#   Saved to data/raw/greens_in_regulation_2008.csv
#
# Downloading scoring_average (120) for 2008
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=120&year=2008
#   Saved to data/raw/scoring_average_2008.csv
#
# Downloading money_earned (109) for 2008
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=109&year=2008
#   Saved to data/raw/money_earned_2008.csv
#
# Downloading fedex_rank (02671) for 2008
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02671&year=2008
#   Saved to data/raw/fedex_rank_2008.csv
#
# Downloading sg_total (02675) for 2009
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02675&year=2009
#   Saved to data/raw/sg_total_2009.csv
#
# Downloading sg_ott (02567) for 2009
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02567&year=2009
#   Saved to data/raw/sg_ott_2009.csv
#
# Downloading sg_app (02568) for 2009
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02568&year=2009
#   Saved to data/raw/sg_app_2009.csv
#
# Downloading sg_arg (02569) for 2009
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02569&year=2009
#   Saved to data/raw/sg_arg_2009.csv
#
# Downloading sg_putt (02564) for 2009
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02564&year=2009
#   Saved to data/raw/sg_putt_2009.csv
#
# Downloading driving_distance (101) for 2009
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=101&year=2009
#   Saved to data/raw/driving_distance_2009.csv
#
# Downloading driving_accuracy (102) for 2009
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=102&year=2009
#   Saved to data/raw/driving_accuracy_2009.csv
#
# Downloading greens_in_regulation (103) for 2009
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=103&year=2009
#   Saved to data/raw/greens_in_regulation_2009.csv
#
# Downloading scoring_average (120) for 2009
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=120&year=2009
#   Saved to data/raw/scoring_average_2009.csv
#
# Downloading money_earned (109) for 2009
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=109&year=2009
#   Saved to data/raw/money_earned_2009.csv
#
# Downloading fedex_rank (02671) for 2009
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02671&year=2009
#   Saved to data/raw/fedex_rank_2009.csv
#
# Downloading sg_total (02675) for 2010
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02675&year=2010
#   Saved to data/raw/sg_total_2010.csv
#
# Downloading sg_ott (02567) for 2010
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02567&year=2010
#   Saved to data/raw/sg_ott_2010.csv
#
# Downloading sg_app (02568) for 2010
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02568&year=2010
#   Saved to data/raw/sg_app_2010.csv
#
# Downloading sg_arg (02569) for 2010
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02569&year=2010
#   Saved to data/raw/sg_arg_2010.csv
#
# Downloading sg_putt (02564) for 2010
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02564&year=2010
#   Saved to data/raw/sg_putt_2010.csv
#
# Downloading driving_distance (101) for 2010
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=101&year=2010
#   Saved to data/raw/driving_distance_2010.csv
#
# Downloading driving_accuracy (102) for 2010
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=102&year=2010
#   Saved to data/raw/driving_accuracy_2010.csv
#
# Downloading greens_in_regulation (103) for 2010
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=103&year=2010
#   Saved to data/raw/greens_in_regulation_2010.csv
#
# Downloading scoring_average (120) for 2010
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=120&year=2010
#   Saved to data/raw/scoring_average_2010.csv
#
# Downloading money_earned (109) for 2010
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=109&year=2010
#   Saved to data/raw/money_earned_2010.csv
#
# Downloading fedex_rank (02671) for 2010
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02671&year=2010
#   Saved to data/raw/fedex_rank_2010.csv
#
# Downloading sg_total (02675) for 2011
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02675&year=2011
#   Saved to data/raw/sg_total_2011.csv
#
# Downloading sg_ott (02567) for 2011
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02567&year=2011
#   Saved to data/raw/sg_ott_2011.csv
#
# Downloading sg_app (02568) for 2011
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02568&year=2011
#   Saved to data/raw/sg_app_2011.csv
#
# Downloading sg_arg (02569) for 2011
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02569&year=2011
#   Saved to data/raw/sg_arg_2011.csv
#
# Downloading sg_putt (02564) for 2011
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02564&year=2011
#   Saved to data/raw/sg_putt_2011.csv
#
# Downloading driving_distance (101) for 2011
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=101&year=2011
#   Saved to data/raw/driving_distance_2011.csv
#
# Downloading driving_accuracy (102) for 2011
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=102&year=2011
#   Saved to data/raw/driving_accuracy_2011.csv
#
# Downloading greens_in_regulation (103) for 2011
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=103&year=2011
#   Saved to data/raw/greens_in_regulation_2011.csv
#
# Downloading scoring_average (120) for 2011
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=120&year=2011
#   Saved to data/raw/scoring_average_2011.csv
#
# Downloading money_earned (109) for 2011
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=109&year=2011
#   Saved to data/raw/money_earned_2011.csv
#
# Downloading fedex_rank (02671) for 2011
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02671&year=2011
#   Saved to data/raw/fedex_rank_2011.csv
#
# Downloading sg_total (02675) for 2012
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02675&year=2012
#   Saved to data/raw/sg_total_2012.csv
#
# Downloading sg_ott (02567) for 2012
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02567&year=2012
#   Saved to data/raw/sg_ott_2012.csv
#
# Downloading sg_app (02568) for 2012
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02568&year=2012
#   Saved to data/raw/sg_app_2012.csv
#
# Downloading sg_arg (02569) for 2012
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02569&year=2012
#   Saved to data/raw/sg_arg_2012.csv
#
# Downloading sg_putt (02564) for 2012
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02564&year=2012
#   Saved to data/raw/sg_putt_2012.csv
#
# Downloading driving_distance (101) for 2012
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=101&year=2012
#   Saved to data/raw/driving_distance_2012.csv
#
# Downloading driving_accuracy (102) for 2012
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=102&year=2012
#   Saved to data/raw/driving_accuracy_2012.csv
#
# Downloading greens_in_regulation (103) for 2012
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=103&year=2012
#   Saved to data/raw/greens_in_regulation_2012.csv
#
# Downloading scoring_average (120) for 2012
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=120&year=2012
#   Saved to data/raw/scoring_average_2012.csv
#
# Downloading money_earned (109) for 2012
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=109&year=2012
#   Saved to data/raw/money_earned_2012.csv
#
# Downloading fedex_rank (02671) for 2012
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02671&year=2012
#   Saved to data/raw/fedex_rank_2012.csv
#
# Downloading sg_total (02675) for 2013
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02675&year=2013
#   Saved to data/raw/sg_total_2013.csv
#
# Downloading sg_ott (02567) for 2013
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02567&year=2013
#   Saved to data/raw/sg_ott_2013.csv
#
# Downloading sg_app (02568) for 2013
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02568&year=2013
#   Saved to data/raw/sg_app_2013.csv
#
# Downloading sg_arg (02569) for 2013
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02569&year=2013
#   Saved to data/raw/sg_arg_2013.csv
#
# Downloading sg_putt (02564) for 2013
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02564&year=2013
#   Saved to data/raw/sg_putt_2013.csv
#
# Downloading driving_distance (101) for 2013
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=101&year=2013
#   Saved to data/raw/driving_distance_2013.csv
#
# Downloading driving_accuracy (102) for 2013
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=102&year=2013
#   Saved to data/raw/driving_accuracy_2013.csv
#
# Downloading greens_in_regulation (103) for 2013
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=103&year=2013
#   Saved to data/raw/greens_in_regulation_2013.csv
#
# Downloading scoring_average (120) for 2013
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=120&year=2013
#   Saved to data/raw/scoring_average_2013.csv
#
# Downloading money_earned (109) for 2013
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=109&year=2013
#   Saved to data/raw/money_earned_2013.csv
#
# Downloading fedex_rank (02671) for 2013
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02671&year=2013
#   Saved to data/raw/fedex_rank_2013.csv
#
# Downloading sg_total (02675) for 2014
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02675&year=2014
#   Saved to data/raw/sg_total_2014.csv
#
# Downloading sg_ott (02567) for 2014
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02567&year=2014
#   Saved to data/raw/sg_ott_2014.csv
#
# Downloading sg_app (02568) for 2014
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02568&year=2014
#   Saved to data/raw/sg_app_2014.csv
#
# Downloading sg_arg (02569) for 2014
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02569&year=2014
#   Saved to data/raw/sg_arg_2014.csv
#
# Downloading sg_putt (02564) for 2014
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02564&year=2014
#   Saved to data/raw/sg_putt_2014.csv
#
# Downloading driving_distance (101) for 2014
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=101&year=2014
#   Saved to data/raw/driving_distance_2014.csv
#
# Downloading driving_accuracy (102) for 2014
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=102&year=2014
#   Saved to data/raw/driving_accuracy_2014.csv
#
# Downloading greens_in_regulation (103) for 2014
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=103&year=2014
#   Saved to data/raw/greens_in_regulation_2014.csv
#
# Downloading scoring_average (120) for 2014
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=120&year=2014
#   Saved to data/raw/scoring_average_2014.csv
#
# Downloading money_earned (109) for 2014
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=109&year=2014
#   Saved to data/raw/money_earned_2014.csv
#
# Downloading fedex_rank (02671) for 2014
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02671&year=2014
#   Saved to data/raw/fedex_rank_2014.csv
#
# Downloading sg_total (02675) for 2015
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02675&year=2015
#   Saved to data/raw/sg_total_2015.csv
#
# Downloading sg_ott (02567) for 2015
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02567&year=2015
#   Saved to data/raw/sg_ott_2015.csv
#
# Downloading sg_app (02568) for 2015
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02568&year=2015
#   Saved to data/raw/sg_app_2015.csv
#
# Downloading sg_arg (02569) for 2015
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02569&year=2015
#   Saved to data/raw/sg_arg_2015.csv
#
# Downloading sg_putt (02564) for 2015
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02564&year=2015
#   Saved to data/raw/sg_putt_2015.csv
#
# Downloading driving_distance (101) for 2015
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=101&year=2015
#   Saved to data/raw/driving_distance_2015.csv
#
# Downloading driving_accuracy (102) for 2015
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=102&year=2015
#   Saved to data/raw/driving_accuracy_2015.csv
#
# Downloading greens_in_regulation (103) for 2015
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=103&year=2015
#   Saved to data/raw/greens_in_regulation_2015.csv
#
# Downloading scoring_average (120) for 2015
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=120&year=2015
#   Saved to data/raw/scoring_average_2015.csv
#
# Downloading money_earned (109) for 2015
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=109&year=2015
#   Saved to data/raw/money_earned_2015.csv
#
# Downloading fedex_rank (02671) for 2015
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02671&year=2015
#   Saved to data/raw/fedex_rank_2015.csv
#
# Downloading sg_total (02675) for 2016
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02675&year=2016
#   Saved to data/raw/sg_total_2016.csv
#
# Downloading sg_ott (02567) for 2016
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02567&year=2016
#   Saved to data/raw/sg_ott_2016.csv
#
# Downloading sg_app (02568) for 2016
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02568&year=2016
#   Saved to data/raw/sg_app_2016.csv
#
# Downloading sg_arg (02569) for 2016
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02569&year=2016
#   Saved to data/raw/sg_arg_2016.csv
#
# Downloading sg_putt (02564) for 2016
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02564&year=2016
#   Saved to data/raw/sg_putt_2016.csv
#
# Downloading driving_distance (101) for 2016
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=101&year=2016
#   Saved to data/raw/driving_distance_2016.csv
#
# Downloading driving_accuracy (102) for 2016
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=102&year=2016
#   Saved to data/raw/driving_accuracy_2016.csv
#
# Downloading greens_in_regulation (103) for 2016
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=103&year=2016
#   Saved to data/raw/greens_in_regulation_2016.csv
#
# Downloading scoring_average (120) for 2016
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=120&year=2016
#   Saved to data/raw/scoring_average_2016.csv
#
# Downloading money_earned (109) for 2016
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=109&year=2016
#   Saved to data/raw/money_earned_2016.csv
#
# Downloading fedex_rank (02671) for 2016
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02671&year=2016
#   Saved to data/raw/fedex_rank_2016.csv
#
# Downloading sg_total (02675) for 2017
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02675&year=2017
#   Saved to data/raw/sg_total_2017.csv
#
# Downloading sg_ott (02567) for 2017
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02567&year=2017
#   Saved to data/raw/sg_ott_2017.csv
#
# Downloading sg_app (02568) for 2017
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02568&year=2017
#   Saved to data/raw/sg_app_2017.csv
#
# Downloading sg_arg (02569) for 2017
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02569&year=2017
#   Saved to data/raw/sg_arg_2017.csv
#
# Downloading sg_putt (02564) for 2017
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02564&year=2017
#   Saved to data/raw/sg_putt_2017.csv
#
# Downloading driving_distance (101) for 2017
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=101&year=2017
#   Saved to data/raw/driving_distance_2017.csv
#
# Downloading driving_accuracy (102) for 2017
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=102&year=2017
#   Saved to data/raw/driving_accuracy_2017.csv
#
# Downloading greens_in_regulation (103) for 2017
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=103&year=2017
#   Saved to data/raw/greens_in_regulation_2017.csv
#
# Downloading scoring_average (120) for 2017
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=120&year=2017
#   Saved to data/raw/scoring_average_2017.csv
#
# Downloading money_earned (109) for 2017
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=109&year=2017
#   Saved to data/raw/money_earned_2017.csv
#
# Downloading fedex_rank (02671) for 2017
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02671&year=2017
#   Saved to data/raw/fedex_rank_2017.csv
#
# Downloading sg_total (02675) for 2018
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02675&year=2018
#   Saved to data/raw/sg_total_2018.csv
#
# Downloading sg_ott (02567) for 2018
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02567&year=2018
#   Saved to data/raw/sg_ott_2018.csv
#
# Downloading sg_app (02568) for 2018
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02568&year=2018
#   Saved to data/raw/sg_app_2018.csv
#
# Downloading sg_arg (02569) for 2018
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02569&year=2018
#   Saved to data/raw/sg_arg_2018.csv
#
# Downloading sg_putt (02564) for 2018
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02564&year=2018
#   Saved to data/raw/sg_putt_2018.csv
#
# Downloading driving_distance (101) for 2018
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=101&year=2018
#   Saved to data/raw/driving_distance_2018.csv
#
# Downloading driving_accuracy (102) for 2018
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=102&year=2018
#   Saved to data/raw/driving_accuracy_2018.csv
#
# Downloading greens_in_regulation (103) for 2018
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=103&year=2018
#   Saved to data/raw/greens_in_regulation_2018.csv
#
# Downloading scoring_average (120) for 2018
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=120&year=2018
#   Saved to data/raw/scoring_average_2018.csv
#
# Downloading money_earned (109) for 2018
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=109&year=2018
#   Saved to data/raw/money_earned_2018.csv
#
# Downloading fedex_rank (02671) for 2018
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02671&year=2018
#   Saved to data/raw/fedex_rank_2018.csv
#
# Downloading sg_total (02675) for 2019
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02675&year=2019
#   Saved to data/raw/sg_total_2019.csv
#
# Downloading sg_ott (02567) for 2019
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02567&year=2019
#   Saved to data/raw/sg_ott_2019.csv
#
# Downloading sg_app (02568) for 2019
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02568&year=2019
#   Saved to data/raw/sg_app_2019.csv
#
# Downloading sg_arg (02569) for 2019
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02569&year=2019
#   Saved to data/raw/sg_arg_2019.csv
#
# Downloading sg_putt (02564) for 2019
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02564&year=2019
#   Saved to data/raw/sg_putt_2019.csv
#
# Downloading driving_distance (101) for 2019
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=101&year=2019
#   Saved to data/raw/driving_distance_2019.csv
#
# Downloading driving_accuracy (102) for 2019
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=102&year=2019
#   Saved to data/raw/driving_accuracy_2019.csv
#
# Downloading greens_in_regulation (103) for 2019
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=103&year=2019
#   Saved to data/raw/greens_in_regulation_2019.csv
#
# Downloading scoring_average (120) for 2019
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=120&year=2019
#   Saved to data/raw/scoring_average_2019.csv
#
# Downloading money_earned (109) for 2019
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=109&year=2019
#   Saved to data/raw/money_earned_2019.csv
#
# Downloading fedex_rank (02671) for 2019
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02671&year=2019
#   Saved to data/raw/fedex_rank_2019.csv
#
# Downloading sg_total (02675) for 2020
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02675&year=2020
#   Saved to data/raw/sg_total_2020.csv
#
# Downloading sg_ott (02567) for 2020
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02567&year=2020
#   Saved to data/raw/sg_ott_2020.csv
#
# Downloading sg_app (02568) for 2020
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02568&year=2020
#   Saved to data/raw/sg_app_2020.csv
#
# Downloading sg_arg (02569) for 2020
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02569&year=2020
#   Saved to data/raw/sg_arg_2020.csv
#
# Downloading sg_putt (02564) for 2020
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02564&year=2020
#   Saved to data/raw/sg_putt_2020.csv
#
# Downloading driving_distance (101) for 2020
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=101&year=2020
#   Saved to data/raw/driving_distance_2020.csv
#
# Downloading driving_accuracy (102) for 2020
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=102&year=2020
#   Saved to data/raw/driving_accuracy_2020.csv
#
# Downloading greens_in_regulation (103) for 2020
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=103&year=2020
#   Saved to data/raw/greens_in_regulation_2020.csv
#
# Downloading scoring_average (120) for 2020
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=120&year=2020
#   Saved to data/raw/scoring_average_2020.csv
#
# Downloading money_earned (109) for 2020
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=109&year=2020
#   Saved to data/raw/money_earned_2020.csv
#
# Downloading fedex_rank (02671) for 2020
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02671&year=2020
#   Saved to data/raw/fedex_rank_2020.csv
#
# Downloading sg_total (02675) for 2021
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02675&year=2021
#   Saved to data/raw/sg_total_2021.csv
#
# Downloading sg_ott (02567) for 2021
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02567&year=2021
#   Saved to data/raw/sg_ott_2021.csv
#
# Downloading sg_app (02568) for 2021
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02568&year=2021
#   Saved to data/raw/sg_app_2021.csv
#
# Downloading sg_arg (02569) for 2021
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02569&year=2021
#   Saved to data/raw/sg_arg_2021.csv
#
# Downloading sg_putt (02564) for 2021
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02564&year=2021
#   Saved to data/raw/sg_putt_2021.csv
#
# Downloading driving_distance (101) for 2021
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=101&year=2021
#   Saved to data/raw/driving_distance_2021.csv
#
# Downloading driving_accuracy (102) for 2021
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=102&year=2021
#   Saved to data/raw/driving_accuracy_2021.csv
#
# Downloading greens_in_regulation (103) for 2021
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=103&year=2021
#   Saved to data/raw/greens_in_regulation_2021.csv
#
# Downloading scoring_average (120) for 2021
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=120&year=2021
#   Saved to data/raw/scoring_average_2021.csv
#
# Downloading money_earned (109) for 2021
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=109&year=2021
#   Saved to data/raw/money_earned_2021.csv
#
# Downloading fedex_rank (02671) for 2021
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02671&year=2021
#   Saved to data/raw/fedex_rank_2021.csv
#
# Downloading sg_total (02675) for 2022
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02675&year=2022
#   Saved to data/raw/sg_total_2022.csv
#
# Downloading sg_ott (02567) for 2022
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02567&year=2022
#   Saved to data/raw/sg_ott_2022.csv
#
# Downloading sg_app (02568) for 2022
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02568&year=2022
#   Saved to data/raw/sg_app_2022.csv
#
# Downloading sg_arg (02569) for 2022
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02569&year=2022
#   Saved to data/raw/sg_arg_2022.csv
#
# Downloading sg_putt (02564) for 2022
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02564&year=2022
#   Saved to data/raw/sg_putt_2022.csv
#
# Downloading driving_distance (101) for 2022
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=101&year=2022
#   Saved to data/raw/driving_distance_2022.csv
#
# Downloading driving_accuracy (102) for 2022
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=102&year=2022
#   Saved to data/raw/driving_accuracy_2022.csv
#
# Downloading greens_in_regulation (103) for 2022
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=103&year=2022
#   Saved to data/raw/greens_in_regulation_2022.csv
#
# Downloading scoring_average (120) for 2022
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=120&year=2022
#   Saved to data/raw/scoring_average_2022.csv
#
# Downloading money_earned (109) for 2022
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=109&year=2022
#   Saved to data/raw/money_earned_2022.csv
#
# Downloading fedex_rank (02671) for 2022
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02671&year=2022
#   Saved to data/raw/fedex_rank_2022.csv
#
# Downloading sg_total (02675) for 2023
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02675&year=2023
#   Saved to data/raw/sg_total_2023.csv
#
# Downloading sg_ott (02567) for 2023
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02567&year=2023
#   Saved to data/raw/sg_ott_2023.csv
#
# Downloading sg_app (02568) for 2023
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02568&year=2023
#   Saved to data/raw/sg_app_2023.csv
#
# Downloading sg_arg (02569) for 2023
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02569&year=2023
#   Saved to data/raw/sg_arg_2023.csv
#
# Downloading sg_putt (02564) for 2023
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02564&year=2023
#   Saved to data/raw/sg_putt_2023.csv
#
# Downloading driving_distance (101) for 2023
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=101&year=2023
#   Saved to data/raw/driving_distance_2023.csv
#
# Downloading driving_accuracy (102) for 2023
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=102&year=2023
#   Saved to data/raw/driving_accuracy_2023.csv
#
# Downloading greens_in_regulation (103) for 2023
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=103&year=2023
#   Saved to data/raw/greens_in_regulation_2023.csv
#
# Downloading scoring_average (120) for 2023
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=120&year=2023
#   Saved to data/raw/scoring_average_2023.csv
#
# Downloading money_earned (109) for 2023
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=109&year=2023
#   Saved to data/raw/money_earned_2023.csv
#
# Downloading fedex_rank (02671) for 2023
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02671&year=2023
#   Saved to data/raw/fedex_rank_2023.csv
#
# Downloading sg_total (02675) for 2024
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02675&year=2024
#   Saved to data/raw/sg_total_2024.csv
#
# Downloading sg_ott (02567) for 2024
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02567&year=2024
#   Saved to data/raw/sg_ott_2024.csv
#
# Downloading sg_app (02568) for 2024
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02568&year=2024
#   Saved to data/raw/sg_app_2024.csv
#
# Downloading sg_arg (02569) for 2024
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02569&year=2024
#   Saved to data/raw/sg_arg_2024.csv
#
# Downloading sg_putt (02564) for 2024
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02564&year=2024
#   Saved to data/raw/sg_putt_2024.csv
#
# Downloading driving_distance (101) for 2024
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=101&year=2024
#   Saved to data/raw/driving_distance_2024.csv
#
# Downloading driving_accuracy (102) for 2024
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=102&year=2024
#   Saved to data/raw/driving_accuracy_2024.csv
#
# Downloading greens_in_regulation (103) for 2024
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=103&year=2024
#   Saved to data/raw/greens_in_regulation_2024.csv
#
# Downloading scoring_average (120) for 2024
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=120&year=2024
#   Saved to data/raw/scoring_average_2024.csv
#
# Downloading money_earned (109) for 2024
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=109&year=2024
#   Saved to data/raw/money_earned_2024.csv
#
# Downloading fedex_rank (02671) for 2024
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02671&year=2024
#   Saved to data/raw/fedex_rank_2024.csv
#
# Downloading sg_total (02675) for 2025
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02675&year=2025
#   Saved to data/raw/sg_total_2025.csv
#
# Downloading sg_ott (02567) for 2025
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02567&year=2025
#   Saved to data/raw/sg_ott_2025.csv
#
# Downloading sg_app (02568) for 2025
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02568&year=2025
#   Saved to data/raw/sg_app_2025.csv
#
# Downloading sg_arg (02569) for 2025
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02569&year=2025
#   Saved to data/raw/sg_arg_2025.csv
#
# Downloading sg_putt (02564) for 2025
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02564&year=2025
#   Saved to data/raw/sg_putt_2025.csv
#
# Downloading driving_distance (101) for 2025
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=101&year=2025
#   Saved to data/raw/driving_distance_2025.csv
#
# Downloading driving_accuracy (102) for 2025
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=102&year=2025
#   Saved to data/raw/driving_accuracy_2025.csv
#
# Downloading greens_in_regulation (103) for 2025
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=103&year=2025
#   Saved to data/raw/greens_in_regulation_2025.csv
#
# Downloading scoring_average (120) for 2025
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=120&year=2025
#   Saved to data/raw/scoring_average_2025.csv
#
# Downloading money_earned (109) for 2025
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=109&year=2025
#   Saved to data/raw/money_earned_2025.csv
#
# Downloading fedex_rank (02671) for 2025
#   URL: https://www.pgatour.com/api/stats-download?timePeriod=THROUGH_EVENT&tourCode=R&statsId=02671&year=2025
#   Saved to data/raw/fedex_rank_2025.csv
#
# All CSV files downloaded successfully!

# %%
# %run src/parse_stats.py
# Out:
# Wrote intermediate file: data/intermediate/driving_accuracy_2007.csv (196 rows)
# Wrote intermediate file: data/intermediate/driving_accuracy_2008.csv (196 rows)
# Wrote intermediate file: data/intermediate/driving_accuracy_2009.csv (184 rows)
# Wrote intermediate file: data/intermediate/driving_accuracy_2010.csv (192 rows)
# Wrote intermediate file: data/intermediate/driving_accuracy_2011.csv (186 rows)
# Wrote intermediate file: data/intermediate/driving_accuracy_2012.csv (191 rows)
# Wrote intermediate file: data/intermediate/driving_accuracy_2013.csv (180 rows)
# Wrote intermediate file: data/intermediate/driving_accuracy_2014.csv (177 rows)
# Wrote intermediate file: data/intermediate/driving_accuracy_2015.csv (184 rows)
# Wrote intermediate file: data/intermediate/driving_accuracy_2016.csv (185 rows)
# Wrote intermediate file: data/intermediate/driving_accuracy_2017.csv (190 rows)
# Wrote intermediate file: data/intermediate/driving_accuracy_2018.csv (193 rows)
# Wrote intermediate file: data/intermediate/driving_accuracy_2019.csv (188 rows)
# Wrote intermediate file: data/intermediate/driving_accuracy_2020.csv (193 rows)
# Wrote intermediate file: data/intermediate/driving_accuracy_2021.csv (196 rows)
# Wrote intermediate file: data/intermediate/driving_accuracy_2022.csv (193 rows)
# Wrote intermediate file: data/intermediate/driving_accuracy_2023.csv (193 rows)
# Wrote intermediate file: data/intermediate/driving_accuracy_2024.csv (184 rows)
# Wrote intermediate file: data/intermediate/driving_accuracy_2025.csv (180 rows)
# Wrote intermediate file: data/intermediate/driving_distance_2007.csv (196 rows)
# Wrote intermediate file: data/intermediate/driving_distance_2008.csv (196 rows)
# Wrote intermediate file: data/intermediate/driving_distance_2009.csv (184 rows)
# Wrote intermediate file: data/intermediate/driving_distance_2010.csv (192 rows)
# Wrote intermediate file: data/intermediate/driving_distance_2011.csv (186 rows)
# Wrote intermediate file: data/intermediate/driving_distance_2012.csv (191 rows)
# Wrote intermediate file: data/intermediate/driving_distance_2013.csv (180 rows)
# Wrote intermediate file: data/intermediate/driving_distance_2014.csv (177 rows)
# Wrote intermediate file: data/intermediate/driving_distance_2015.csv (184 rows)
# Wrote intermediate file: data/intermediate/driving_distance_2016.csv (185 rows)
# Wrote intermediate file: data/intermediate/driving_distance_2017.csv (190 rows)
# Wrote intermediate file: data/intermediate/driving_distance_2018.csv (193 rows)
# Wrote intermediate file: data/intermediate/driving_distance_2019.csv (188 rows)
# Wrote intermediate file: data/intermediate/driving_distance_2020.csv (193 rows)
# Wrote intermediate file: data/intermediate/driving_distance_2021.csv (196 rows)
# Wrote intermediate file: data/intermediate/driving_distance_2022.csv (193 rows)
# Wrote intermediate file: data/intermediate/driving_distance_2023.csv (193 rows)
# Wrote intermediate file: data/intermediate/driving_distance_2024.csv (184 rows)
# Wrote intermediate file: data/intermediate/driving_distance_2025.csv (180 rows)
# Wrote intermediate file: data/intermediate/fedex_rank_2007.csv (253 rows)
# Wrote intermediate file: data/intermediate/fedex_rank_2008.csv (261 rows)
# Wrote intermediate file: data/intermediate/fedex_rank_2009.csv (255 rows)
# Wrote intermediate file: data/intermediate/fedex_rank_2010.csv (248 rows)
# Wrote intermediate file: data/intermediate/fedex_rank_2011.csv (264 rows)
# Wrote intermediate file: data/intermediate/fedex_rank_2012.csv (257 rows)
# Wrote intermediate file: data/intermediate/fedex_rank_2013.csv (253 rows)
# Wrote intermediate file: data/intermediate/fedex_rank_2014.csv (258 rows)
# Wrote intermediate file: data/intermediate/fedex_rank_2015.csv (150 rows)
# Wrote intermediate file: data/intermediate/fedex_rank_2016.csv (150 rows)
# Wrote intermediate file: data/intermediate/fedex_rank_2017.csv (150 rows)
# Wrote intermediate file: data/intermediate/fedex_rank_2018.csv (150 rows)
# Wrote intermediate file: data/intermediate/fedex_rank_2019.csv (150 rows)
# Wrote intermediate file: data/intermediate/fedex_rank_2020.csv (150 rows)
# Wrote intermediate file: data/intermediate/fedex_rank_2021.csv (150 rows)
# Wrote intermediate file: data/intermediate/fedex_rank_2022.csv (150 rows)
# Wrote intermediate file: data/intermediate/fedex_rank_2023.csv (240 rows)
# Wrote intermediate file: data/intermediate/fedex_rank_2024.csv (239 rows)
# Wrote intermediate file: data/intermediate/fedex_rank_2025.csv (237 rows)
# Wrote intermediate file: data/intermediate/greens_in_regulation_2007.csv (196 rows)
# Wrote intermediate file: data/intermediate/greens_in_regulation_2008.csv (196 rows)
# Wrote intermediate file: data/intermediate/greens_in_regulation_2009.csv (184 rows)
# Wrote intermediate file: data/intermediate/greens_in_regulation_2010.csv (192 rows)
# Wrote intermediate file: data/intermediate/greens_in_regulation_2011.csv (186 rows)
# Wrote intermediate file: data/intermediate/greens_in_regulation_2012.csv (191 rows)
# Wrote intermediate file: data/intermediate/greens_in_regulation_2013.csv (180 rows)
# Wrote intermediate file: data/intermediate/greens_in_regulation_2014.csv (177 rows)
# Wrote intermediate file: data/intermediate/greens_in_regulation_2015.csv (184 rows)
# Wrote intermediate file: data/intermediate/greens_in_regulation_2016.csv (185 rows)
# Wrote intermediate file: data/intermediate/greens_in_regulation_2017.csv (190 rows)
# Wrote intermediate file: data/intermediate/greens_in_regulation_2018.csv (193 rows)
# Wrote intermediate file: data/intermediate/greens_in_regulation_2019.csv (188 rows)
# Wrote intermediate file: data/intermediate/greens_in_regulation_2020.csv (193 rows)
# Wrote intermediate file: data/intermediate/greens_in_regulation_2021.csv (196 rows)
# Wrote intermediate file: data/intermediate/greens_in_regulation_2022.csv (193 rows)
# Wrote intermediate file: data/intermediate/greens_in_regulation_2023.csv (193 rows)
# Wrote intermediate file: data/intermediate/greens_in_regulation_2024.csv (184 rows)
# Wrote intermediate file: data/intermediate/greens_in_regulation_2025.csv (180 rows)
# Wrote intermediate file: data/intermediate/money_earned_2007.csv (256 rows)
# Wrote intermediate file: data/intermediate/money_earned_2008.csv (261 rows)
# Wrote intermediate file: data/intermediate/money_earned_2009.csv (258 rows)
# Wrote intermediate file: data/intermediate/money_earned_2010.csv (248 rows)
# Wrote intermediate file: data/intermediate/money_earned_2011.csv (261 rows)
# Wrote intermediate file: data/intermediate/money_earned_2012.csv (258 rows)
# Wrote intermediate file: data/intermediate/money_earned_2013.csv (253 rows)
# Wrote intermediate file: data/intermediate/money_earned_2014.csv (258 rows)
# Wrote intermediate file: data/intermediate/money_earned_2015.csv (259 rows)
# Wrote intermediate file: data/intermediate/money_earned_2016.csv (251 rows)
# Wrote intermediate file: data/intermediate/money_earned_2017.csv (252 rows)
# Wrote intermediate file: data/intermediate/money_earned_2018.csv (260 rows)
# Wrote intermediate file: data/intermediate/money_earned_2019.csv (265 rows)
# Wrote intermediate file: data/intermediate/money_earned_2020.csv (254 rows)
# Wrote intermediate file: data/intermediate/money_earned_2021.csv (252 rows)
# Wrote intermediate file: data/intermediate/money_earned_2022.csv (247 rows)
# Wrote intermediate file: data/intermediate/money_earned_2023.csv (241 rows)
# Wrote intermediate file: data/intermediate/money_earned_2024.csv (245 rows)
# Wrote intermediate file: data/intermediate/money_earned_2025.csv (236 rows)
# Wrote intermediate file: data/intermediate/scoring_average_2007.csv (196 rows)
# Wrote intermediate file: data/intermediate/scoring_average_2008.csv (196 rows)
# Wrote intermediate file: data/intermediate/scoring_average_2009.csv (184 rows)
# Wrote intermediate file: data/intermediate/scoring_average_2010.csv (192 rows)
# Wrote intermediate file: data/intermediate/scoring_average_2011.csv (186 rows)
# Wrote intermediate file: data/intermediate/scoring_average_2012.csv (191 rows)
# Wrote intermediate file: data/intermediate/scoring_average_2013.csv (180 rows)
# Wrote intermediate file: data/intermediate/scoring_average_2014.csv (177 rows)
# Wrote intermediate file: data/intermediate/scoring_average_2015.csv (184 rows)
# Wrote intermediate file: data/intermediate/scoring_average_2016.csv (185 rows)
# Wrote intermediate file: data/intermediate/scoring_average_2017.csv (190 rows)
# Wrote intermediate file: data/intermediate/scoring_average_2018.csv (193 rows)
# Wrote intermediate file: data/intermediate/scoring_average_2019.csv (188 rows)
# Wrote intermediate file: data/intermediate/scoring_average_2020.csv (193 rows)
# Wrote intermediate file: data/intermediate/scoring_average_2021.csv (196 rows)
# Wrote intermediate file: data/intermediate/scoring_average_2022.csv (191 rows)
# Wrote intermediate file: data/intermediate/scoring_average_2023.csv (193 rows)
# Wrote intermediate file: data/intermediate/scoring_average_2024.csv (184 rows)
# Wrote intermediate file: data/intermediate/scoring_average_2025.csv (179 rows)
# Wrote intermediate file: data/intermediate/sg_app_2007.csv (196 rows)
# Wrote intermediate file: data/intermediate/sg_app_2008.csv (196 rows)
# Wrote intermediate file: data/intermediate/sg_app_2009.csv (184 rows)
# Wrote intermediate file: data/intermediate/sg_app_2010.csv (192 rows)
# Wrote intermediate file: data/intermediate/sg_app_2011.csv (186 rows)
# Wrote intermediate file: data/intermediate/sg_app_2012.csv (191 rows)
# Wrote intermediate file: data/intermediate/sg_app_2013.csv (180 rows)
# Wrote intermediate file: data/intermediate/sg_app_2014.csv (177 rows)
# Wrote intermediate file: data/intermediate/sg_app_2015.csv (184 rows)
# Wrote intermediate file: data/intermediate/sg_app_2016.csv (185 rows)
# Wrote intermediate file: data/intermediate/sg_app_2017.csv (190 rows)
# Wrote intermediate file: data/intermediate/sg_app_2018.csv (193 rows)
# Wrote intermediate file: data/intermediate/sg_app_2019.csv (188 rows)
# Wrote intermediate file: data/intermediate/sg_app_2020.csv (193 rows)
# Wrote intermediate file: data/intermediate/sg_app_2021.csv (196 rows)
# Wrote intermediate file: data/intermediate/sg_app_2022.csv (193 rows)
# Wrote intermediate file: data/intermediate/sg_app_2023.csv (193 rows)
# Wrote intermediate file: data/intermediate/sg_app_2024.csv (184 rows)
# Wrote intermediate file: data/intermediate/sg_app_2025.csv (180 rows)
# Wrote intermediate file: data/intermediate/sg_arg_2007.csv (196 rows)
# Wrote intermediate file: data/intermediate/sg_arg_2008.csv (196 rows)
# Wrote intermediate file: data/intermediate/sg_arg_2009.csv (184 rows)
# Wrote intermediate file: data/intermediate/sg_arg_2010.csv (192 rows)
# Wrote intermediate file: data/intermediate/sg_arg_2011.csv (186 rows)
# Wrote intermediate file: data/intermediate/sg_arg_2012.csv (191 rows)
# Wrote intermediate file: data/intermediate/sg_arg_2013.csv (180 rows)
# Wrote intermediate file: data/intermediate/sg_arg_2014.csv (177 rows)
# Wrote intermediate file: data/intermediate/sg_arg_2015.csv (184 rows)
# Wrote intermediate file: data/intermediate/sg_arg_2016.csv (185 rows)
# Wrote intermediate file: data/intermediate/sg_arg_2017.csv (190 rows)
# Wrote intermediate file: data/intermediate/sg_arg_2018.csv (193 rows)
# Wrote intermediate file: data/intermediate/sg_arg_2019.csv (188 rows)
# Wrote intermediate file: data/intermediate/sg_arg_2020.csv (193 rows)
# Wrote intermediate file: data/intermediate/sg_arg_2021.csv (196 rows)
# Wrote intermediate file: data/intermediate/sg_arg_2022.csv (193 rows)
# Wrote intermediate file: data/intermediate/sg_arg_2023.csv (193 rows)
# Wrote intermediate file: data/intermediate/sg_arg_2024.csv (184 rows)
# Wrote intermediate file: data/intermediate/sg_arg_2025.csv (180 rows)
# Wrote intermediate file: data/intermediate/sg_ott_2007.csv (196 rows)
# Wrote intermediate file: data/intermediate/sg_ott_2008.csv (196 rows)
# Wrote intermediate file: data/intermediate/sg_ott_2009.csv (184 rows)
# Wrote intermediate file: data/intermediate/sg_ott_2010.csv (192 rows)
# Wrote intermediate file: data/intermediate/sg_ott_2011.csv (186 rows)
# Wrote intermediate file: data/intermediate/sg_ott_2012.csv (191 rows)
# Wrote intermediate file: data/intermediate/sg_ott_2013.csv (180 rows)
# Wrote intermediate file: data/intermediate/sg_ott_2014.csv (177 rows)
# Wrote intermediate file: data/intermediate/sg_ott_2015.csv (184 rows)
# Wrote intermediate file: data/intermediate/sg_ott_2016.csv (185 rows)
# Wrote intermediate file: data/intermediate/sg_ott_2017.csv (190 rows)
# Wrote intermediate file: data/intermediate/sg_ott_2018.csv (193 rows)
# Wrote intermediate file: data/intermediate/sg_ott_2019.csv (188 rows)
# Wrote intermediate file: data/intermediate/sg_ott_2020.csv (193 rows)
# Wrote intermediate file: data/intermediate/sg_ott_2021.csv (196 rows)
# Wrote intermediate file: data/intermediate/sg_ott_2022.csv (193 rows)
# Wrote intermediate file: data/intermediate/sg_ott_2023.csv (193 rows)
# Wrote intermediate file: data/intermediate/sg_ott_2024.csv (184 rows)
# Wrote intermediate file: data/intermediate/sg_ott_2025.csv (180 rows)
# Wrote intermediate file: data/intermediate/sg_putt_2007.csv (196 rows)
# Wrote intermediate file: data/intermediate/sg_putt_2008.csv (196 rows)
# Wrote intermediate file: data/intermediate/sg_putt_2009.csv (184 rows)
# Wrote intermediate file: data/intermediate/sg_putt_2010.csv (192 rows)
# Wrote intermediate file: data/intermediate/sg_putt_2011.csv (186 rows)
# Wrote intermediate file: data/intermediate/sg_putt_2012.csv (191 rows)
# Wrote intermediate file: data/intermediate/sg_putt_2013.csv (180 rows)
# Wrote intermediate file: data/intermediate/sg_putt_2014.csv (177 rows)
# Wrote intermediate file: data/intermediate/sg_putt_2015.csv (184 rows)
# Wrote intermediate file: data/intermediate/sg_putt_2016.csv (185 rows)
# Wrote intermediate file: data/intermediate/sg_putt_2017.csv (190 rows)
# Wrote intermediate file: data/intermediate/sg_putt_2018.csv (193 rows)
# Wrote intermediate file: data/intermediate/sg_putt_2019.csv (188 rows)
# Wrote intermediate file: data/intermediate/sg_putt_2020.csv (193 rows)
# Wrote intermediate file: data/intermediate/sg_putt_2021.csv (196 rows)
# Wrote intermediate file: data/intermediate/sg_putt_2022.csv (193 rows)
# Wrote intermediate file: data/intermediate/sg_putt_2023.csv (193 rows)
# Wrote intermediate file: data/intermediate/sg_putt_2024.csv (184 rows)
# Wrote intermediate file: data/intermediate/sg_putt_2025.csv (180 rows)
# Wrote intermediate file: data/intermediate/sg_total_2007.csv (196 rows)
# Wrote intermediate file: data/intermediate/sg_total_2008.csv (196 rows)
# Wrote intermediate file: data/intermediate/sg_total_2009.csv (184 rows)
# Wrote intermediate file: data/intermediate/sg_total_2010.csv (192 rows)
# Wrote intermediate file: data/intermediate/sg_total_2011.csv (186 rows)
# Wrote intermediate file: data/intermediate/sg_total_2012.csv (191 rows)
# Wrote intermediate file: data/intermediate/sg_total_2013.csv (180 rows)
# Wrote intermediate file: data/intermediate/sg_total_2014.csv (177 rows)
# Wrote intermediate file: data/intermediate/sg_total_2015.csv (184 rows)
# Wrote intermediate file: data/intermediate/sg_total_2016.csv (185 rows)
# Wrote intermediate file: data/intermediate/sg_total_2017.csv (190 rows)
# Wrote intermediate file: data/intermediate/sg_total_2018.csv (193 rows)
# Wrote intermediate file: data/intermediate/sg_total_2019.csv (188 rows)
# Wrote intermediate file: data/intermediate/sg_total_2020.csv (193 rows)
# Wrote intermediate file: data/intermediate/sg_total_2021.csv (196 rows)
# Wrote intermediate file: data/intermediate/sg_total_2022.csv (193 rows)
# Wrote intermediate file: data/intermediate/sg_total_2023.csv (193 rows)
# Wrote intermediate file: data/intermediate/sg_total_2024.csv (184 rows)
# Wrote intermediate file: data/intermediate/sg_total_2025.csv (180 rows)
# Parsing complete. Check data/intermediate/ for per-stat CSVs.

# %%
# %run src/build_master.py
# Out:
# Building master dataset for years: [2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025]
#   -> Merging stats for 2007
#     Loaded 11 stats: sg_total, sg_ott, sg_app, sg_arg, sg_putt, driving_distance, driving_accuracy, greens_in_regulation, scoring_average, money_earned, fedex_rank
#     Player counts per stat: {'sg_total': 196, 'sg_ott': 196, 'sg_app': 196, 'sg_arg': 196, 'sg_putt': 196, 'driving_distance': 196, 'driving_accuracy': 196, 'greens_in_regulation': 196, 'scoring_average': 196, 'money_earned': 256, 'fedex_rank': 253}
#     Final merged dataset: 257 players (may be more due to outer join)
#      Saved data/processed/master_2007.csv (257 rows)
#   -> Merging stats for 2008
#     Loaded 11 stats: sg_total, sg_ott, sg_app, sg_arg, sg_putt, driving_distance, driving_accuracy, greens_in_regulation, scoring_average, money_earned, fedex_rank
#     Player counts per stat: {'sg_total': 196, 'sg_ott': 196, 'sg_app': 196, 'sg_arg': 196, 'sg_putt': 196, 'driving_distance': 196, 'driving_accuracy': 196, 'greens_in_regulation': 196, 'scoring_average': 196, 'money_earned': 261, 'fedex_rank': 261}
#     Final merged dataset: 261 players (may be more due to outer join)
#      Saved data/processed/master_2008.csv (261 rows)
#   -> Merging stats for 2009
#     Loaded 11 stats: sg_total, sg_ott, sg_app, sg_arg, sg_putt, driving_distance, driving_accuracy, greens_in_regulation, scoring_average, money_earned, fedex_rank
#     Player counts per stat: {'sg_total': 184, 'sg_ott': 184, 'sg_app': 184, 'sg_arg': 184, 'sg_putt': 184, 'driving_distance': 184, 'driving_accuracy': 184, 'greens_in_regulation': 184, 'scoring_average': 184, 'money_earned': 258, 'fedex_rank': 255}
#     Final merged dataset: 258 players (may be more due to outer join)
#      Saved data/processed/master_2009.csv (258 rows)
#   -> Merging stats for 2010
#     Loaded 11 stats: sg_total, sg_ott, sg_app, sg_arg, sg_putt, driving_distance, driving_accuracy, greens_in_regulation, scoring_average, money_earned, fedex_rank
#     Player counts per stat: {'sg_total': 192, 'sg_ott': 192, 'sg_app': 192, 'sg_arg': 192, 'sg_putt': 192, 'driving_distance': 192, 'driving_accuracy': 192, 'greens_in_regulation': 192, 'scoring_average': 192, 'money_earned': 248, 'fedex_rank': 248}
#     Final merged dataset: 251 players (may be more due to outer join)
#      Saved data/processed/master_2010.csv (251 rows)
#   -> Merging stats for 2011
#     Loaded 11 stats: sg_total, sg_ott, sg_app, sg_arg, sg_putt, driving_distance, driving_accuracy, greens_in_regulation, scoring_average, money_earned, fedex_rank
#     Player counts per stat: {'sg_total': 186, 'sg_ott': 186, 'sg_app': 186, 'sg_arg': 186, 'sg_putt': 186, 'driving_distance': 186, 'driving_accuracy': 186, 'greens_in_regulation': 186, 'scoring_average': 186, 'money_earned': 261, 'fedex_rank': 264}
#     Final merged dataset: 264 players (may be more due to outer join)
#      Saved data/processed/master_2011.csv (264 rows)
#   -> Merging stats for 2012
#     Loaded 11 stats: sg_total, sg_ott, sg_app, sg_arg, sg_putt, driving_distance, driving_accuracy, greens_in_regulation, scoring_average, money_earned, fedex_rank
#     Player counts per stat: {'sg_total': 191, 'sg_ott': 191, 'sg_app': 191, 'sg_arg': 191, 'sg_putt': 191, 'driving_distance': 191, 'driving_accuracy': 191, 'greens_in_regulation': 191, 'scoring_average': 191, 'money_earned': 258, 'fedex_rank': 257}
#     Final merged dataset: 261 players (may be more due to outer join)
#      Saved data/processed/master_2012.csv (261 rows)
#   -> Merging stats for 2013
#     Loaded 11 stats: sg_total, sg_ott, sg_app, sg_arg, sg_putt, driving_distance, driving_accuracy, greens_in_regulation, scoring_average, money_earned, fedex_rank
#     Player counts per stat: {'sg_total': 180, 'sg_ott': 180, 'sg_app': 180, 'sg_arg': 180, 'sg_putt': 180, 'driving_distance': 180, 'driving_accuracy': 180, 'greens_in_regulation': 180, 'scoring_average': 180, 'money_earned': 253, 'fedex_rank': 253}
#     Final merged dataset: 253 players (may be more due to outer join)
#      Saved data/processed/master_2013.csv (253 rows)
#   -> Merging stats for 2014
#     Loaded 11 stats: sg_total, sg_ott, sg_app, sg_arg, sg_putt, driving_distance, driving_accuracy, greens_in_regulation, scoring_average, money_earned, fedex_rank
#     Player counts per stat: {'sg_total': 177, 'sg_ott': 177, 'sg_app': 177, 'sg_arg': 177, 'sg_putt': 177, 'driving_distance': 177, 'driving_accuracy': 177, 'greens_in_regulation': 177, 'scoring_average': 177, 'money_earned': 258, 'fedex_rank': 258}
#     Final merged dataset: 259 players (may be more due to outer join)
#      Saved data/processed/master_2014.csv (259 rows)
#   -> Merging stats for 2015
#     Loaded 11 stats: sg_total, sg_ott, sg_app, sg_arg, sg_putt, driving_distance, driving_accuracy, greens_in_regulation, scoring_average, money_earned, fedex_rank
#     Player counts per stat: {'sg_total': 184, 'sg_ott': 184, 'sg_app': 184, 'sg_arg': 184, 'sg_putt': 184, 'driving_distance': 184, 'driving_accuracy': 184, 'greens_in_regulation': 184, 'scoring_average': 184, 'money_earned': 259, 'fedex_rank': 150}
#     Final merged dataset: 260 players (may be more due to outer join)
#      Saved data/processed/master_2015.csv (260 rows)
#   -> Merging stats for 2016
#     Loaded 11 stats: sg_total, sg_ott, sg_app, sg_arg, sg_putt, driving_distance, driving_accuracy, greens_in_regulation, scoring_average, money_earned, fedex_rank
#     Player counts per stat: {'sg_total': 185, 'sg_ott': 185, 'sg_app': 185, 'sg_arg': 185, 'sg_putt': 185, 'driving_distance': 185, 'driving_accuracy': 185, 'greens_in_regulation': 185, 'scoring_average': 185, 'money_earned': 251, 'fedex_rank': 150}
#     Final merged dataset: 251 players (may be more due to outer join)
#      Saved data/processed/master_2016.csv (251 rows)
#   -> Merging stats for 2017
#     Loaded 11 stats: sg_total, sg_ott, sg_app, sg_arg, sg_putt, driving_distance, driving_accuracy, greens_in_regulation, scoring_average, money_earned, fedex_rank
#     Player counts per stat: {'sg_total': 190, 'sg_ott': 190, 'sg_app': 190, 'sg_arg': 190, 'sg_putt': 190, 'driving_distance': 190, 'driving_accuracy': 190, 'greens_in_regulation': 190, 'scoring_average': 190, 'money_earned': 252, 'fedex_rank': 150}
#     Final merged dataset: 252 players (may be more due to outer join)
#      Saved data/processed/master_2017.csv (252 rows)
#   -> Merging stats for 2018
#     Loaded 11 stats: sg_total, sg_ott, sg_app, sg_arg, sg_putt, driving_distance, driving_accuracy, greens_in_regulation, scoring_average, money_earned, fedex_rank
#     Player counts per stat: {'sg_total': 193, 'sg_ott': 193, 'sg_app': 193, 'sg_arg': 193, 'sg_putt': 193, 'driving_distance': 193, 'driving_accuracy': 193, 'greens_in_regulation': 193, 'scoring_average': 193, 'money_earned': 260, 'fedex_rank': 150}
#     Final merged dataset: 261 players (may be more due to outer join)
#      Saved data/processed/master_2018.csv (261 rows)
#   -> Merging stats for 2019
#     Loaded 11 stats: sg_total, sg_ott, sg_app, sg_arg, sg_putt, driving_distance, driving_accuracy, greens_in_regulation, scoring_average, money_earned, fedex_rank
#     Player counts per stat: {'sg_total': 188, 'sg_ott': 188, 'sg_app': 188, 'sg_arg': 188, 'sg_putt': 188, 'driving_distance': 188, 'driving_accuracy': 188, 'greens_in_regulation': 188, 'scoring_average': 188, 'money_earned': 265, 'fedex_rank': 150}
#     Final merged dataset: 266 players (may be more due to outer join)
#      Saved data/processed/master_2019.csv (266 rows)
#   -> Merging stats for 2020
#     Loaded 11 stats: sg_total, sg_ott, sg_app, sg_arg, sg_putt, driving_distance, driving_accuracy, greens_in_regulation, scoring_average, money_earned, fedex_rank
#     Player counts per stat: {'sg_total': 193, 'sg_ott': 193, 'sg_app': 193, 'sg_arg': 193, 'sg_putt': 193, 'driving_distance': 193, 'driving_accuracy': 193, 'greens_in_regulation': 193, 'scoring_average': 193, 'money_earned': 254, 'fedex_rank': 150}
#     Final merged dataset: 255 players (may be more due to outer join)
#      Saved data/processed/master_2020.csv (255 rows)
#   -> Merging stats for 2021
#     Loaded 11 stats: sg_total, sg_ott, sg_app, sg_arg, sg_putt, driving_distance, driving_accuracy, greens_in_regulation, scoring_average, money_earned, fedex_rank
#     Player counts per stat: {'sg_total': 196, 'sg_ott': 196, 'sg_app': 196, 'sg_arg': 196, 'sg_putt': 196, 'driving_distance': 196, 'driving_accuracy': 196, 'greens_in_regulation': 196, 'scoring_average': 196, 'money_earned': 252, 'fedex_rank': 150}
#     Final merged dataset: 252 players (may be more due to outer join)
#      Saved data/processed/master_2021.csv (252 rows)
#   -> Merging stats for 2022
#     Loaded 11 stats: sg_total, sg_ott, sg_app, sg_arg, sg_putt, driving_distance, driving_accuracy, greens_in_regulation, scoring_average, money_earned, fedex_rank
#     Player counts per stat: {'sg_total': 193, 'sg_ott': 193, 'sg_app': 193, 'sg_arg': 193, 'sg_putt': 193, 'driving_distance': 193, 'driving_accuracy': 193, 'greens_in_regulation': 193, 'scoring_average': 191, 'money_earned': 247, 'fedex_rank': 150}
#     Final merged dataset: 250 players (may be more due to outer join)
#      Saved data/processed/master_2022.csv (250 rows)
#   -> Merging stats for 2023
#     Loaded 11 stats: sg_total, sg_ott, sg_app, sg_arg, sg_putt, driving_distance, driving_accuracy, greens_in_regulation, scoring_average, money_earned, fedex_rank
#     Player counts per stat: {'sg_total': 193, 'sg_ott': 193, 'sg_app': 193, 'sg_arg': 193, 'sg_putt': 193, 'driving_distance': 193, 'driving_accuracy': 193, 'greens_in_regulation': 193, 'scoring_average': 193, 'money_earned': 241, 'fedex_rank': 240}
#     Final merged dataset: 244 players (may be more due to outer join)
#      Saved data/processed/master_2023.csv (244 rows)
#   -> Merging stats for 2024
#     Loaded 11 stats: sg_total, sg_ott, sg_app, sg_arg, sg_putt, driving_distance, driving_accuracy, greens_in_regulation, scoring_average, money_earned, fedex_rank
#     Player counts per stat: {'sg_total': 184, 'sg_ott': 184, 'sg_app': 184, 'sg_arg': 184, 'sg_putt': 184, 'driving_distance': 184, 'driving_accuracy': 184, 'greens_in_regulation': 184, 'scoring_average': 184, 'money_earned': 245, 'fedex_rank': 239}
#     Final merged dataset: 245 players (may be more due to outer join)
#      Saved data/processed/master_2024.csv (245 rows)
#   -> Merging stats for 2025
#     Loaded 11 stats: sg_total, sg_ott, sg_app, sg_arg, sg_putt, driving_distance, driving_accuracy, greens_in_regulation, scoring_average, money_earned, fedex_rank
#     Player counts per stat: {'sg_total': 180, 'sg_ott': 180, 'sg_app': 180, 'sg_arg': 180, 'sg_putt': 180, 'driving_distance': 180, 'driving_accuracy': 180, 'greens_in_regulation': 180, 'scoring_average': 179, 'money_earned': 236, 'fedex_rank': 237}
#     Final merged dataset: 239 players (may be more due to outer join)
#      Saved data/processed/master_2025.csv (239 rows)
#
# Wrote data/processed/master_player_seasons.csv (4839 total rows)

# %% [markdown]
# ### --- IGNORE ABOVE ---

# %% [markdown]
# ### Data Reading
# Run the cell below to read in the processed data.

# %%
PGA = pd.read_csv('data/processed/master_player_seasons.csv')

# %% [markdown]
# ### Definition of Each Metric
#
# The PGA TOUR defines the Strokes Gained (SG) metric as a golf statistic that measures a golfer's performance for a specific shot by comparing it to the average number of strokes it takes other players to complete the hole from that same position. A positive SG value indicates that the golfer took more strokes than the average player to complete the hole from that position (performing worse), while a negative SG value indicates that the golfer took fewer strokes than the average player from that position (performing better). The SG metric can be used to evaluate a golfer's performance compared to the field average for a given shot type. This is done using the following sub-metrics defined below:
#
# - Strokes Gained Off-the-Tee (SG: OTT): Measures a golfer's tee shot performance on Par 4s and Par 5s, comparing how far they  advance the ball versus the field average from that distance/lie. Ultimately, reflecting how much their driving helps or hurts their scoring opportunities compared to the field average.
# - Strokes Gained on Approach (SG: APP): Measures a golfer's performance on shots from the fairway/rough that are further than 30 yards from the flag, measuring accuracy into greens. Ultimately, reflecting how much their approach shots outside of 30 yards help or hurt their scoring opportunities compared to the field average.
# - Strokes Gained Around-the-Green (SG: ARG): Shots within about 30 yards of the green, but not on the putting surface, for example, chipping, pitching, and bunker shots. Ultimately, reflecting how much their short game around the green helps or hurts their scoring opportunities compared to the field average.
# - Strokes Gained Putting (SG: PUT): Compares putting performance from your initial distances to the hole, while on the green, against the field average for those same putts. Ultimately, reflecting how much their putting helps or hurts their scoring opportunities compared to the field average.
# - Strokes Gained Tee-to-Green (SG: T2G): All shots from the tee box until the ball is on the green, showing overall long-game skill. This is just the sum of SG: OTT, SG: APP, and SG: ARG. Ultimately, reflecting how much their long game (driving, approach, and short game) helps or hurts their scoring opportunities compared to the field average.
# - Strokes Gained Total (SG: TOT): The sum of all strokes gained shots, including putting. This is just the sum of SG: T2G and SG: PUT. Ultimately, reflecting how much their overall game (long game and putting) helps or hurts their scoring opportunities compared to the field average.
#
# Additional Statistics:
# - Driving Distance: Average distance (in yards) a golfer hits the ball off the tee on Par 4s and Par 5s.
# - Driving Accuracy: Percentage of times a golfer's tee shot on Par 4s and Par 5s lands in the fairway.
# - Scoring Average: Average number of strokes a golfer takes per round. (Success Metric)
# - Money Earned: Total prize money a golfer has earned in a season (in USD). (Success Metric)
# - FedEx Rank: A points-based ranking system used to determine the top players on the PGA TOUR throughout a given season. (Success Metric)
#
# ### Data Features
# Run the following cells to see the features of the dataset.
#
# #### The dataset is made up of the following columns:
# - year: The year of the season (integer)
# - player_name: The name of the player (string)
# - sg_total: Strokes Gained: Total (float)
# - sg_off_the_tee: Strokes Gained: Off the Tee (float)
# - sg_approach: Strokes Gained: Approach the Green (float)
# - sg_around_the_green: Strokes Gained: Around the Green (float)
# - sg_putting: Strokes Gained: Putting (float)
# - driving_distance: Average Driving Distance in yards (float)
# - driving_accuracy: Driving Accuracy Percentage (float)
# - scoring_average: Scoring Average (float)
# - money_earned: Total Money Earned in USD (float)
# - fedex_rank: FedEx Cup Ranking (float)
# - sg_tee_to_green: Strokes Gained: Tee to Green (float)

# %%
COLS = pd.DataFrame(index=PGA.columns)
COLS.index.name = 'col_id'
COLS['dtypes'] = PGA.dtypes
COLS['n_unique'] = PGA.nunique()
COLS["tot_observations"] = len(PGA)
COLS["na_count"] = PGA.isna().sum()

COLS
# Out:
#                        dtypes  n_unique  tot_observations  na_count
# col_id
# year                    int64        19              4839         0
# player_name            object       806              4839         0
# sg_total              float64      1917              4839      1258
# sg_off_the_tee        float64      1323              4839      1258
# sg_approach           float64      1364              4839      1258
# sg_around_green       float64       958              4839      1258
# sg_putting            float64      1306              4839      1258
# driving_distance      float64       484              4839      1258
# driving_accuracy      float64      1671              4839      1258
# greens_in_regulation  float64      1061              4839      1258
# scoring_average       float64      1954              4839      1261
# money_earned          float64      4774              4839        24
# final_season_rank     float64       264              4839       874
# sg_tee_to_green       float64      2280              4839      1258

# %% [markdown]
# As shown in the `na_count` row of the `COLS` DataFrame, there are missing values in the dataset. These missing values happen when players do not play enough rounds in a season to qualify for the advacned stats metrics, they never made the cut at a tournament (you need to make the cut in order to get paid), or they played in a tournament with a sponsors exemption, which means they could've won money, but don't have any other stats to track. To ensure the integrity of the analysis and create a clean dataset, I will remove any rows with missing values.

# %%
PGA_clean = PGA.copy().dropna()

# %%
COLS_clean = pd.DataFrame(index=PGA_clean.columns)
COLS_clean.index.name = 'col_id'
COLS_clean['dtypes'] = PGA_clean.dtypes
COLS_clean['n_unique'] = PGA_clean.nunique()
COLS_clean["tot_observations"] = len(PGA_clean)
COLS_clean["na_count"] = PGA_clean.isna().sum()
COLS_clean
# Out:
#                        dtypes  n_unique  tot_observations  na_count
# col_id
# year                    int64        19              3218         0
# player_name            object       670              3218         0
# sg_total              float64      1762              3218         0
# sg_off_the_tee        float64      1251              3218         0
# sg_approach           float64      1296              3218         0
# sg_around_green       float64       925              3218         0
# sg_putting            float64      1250              3218         0
# driving_distance      float64       477              3218         0
# driving_accuracy      float64      1591              3218         0
# greens_in_regulation  float64      1018              3218         0
# scoring_average       float64      1788              3218         0
# money_earned          float64      3216              3218         0
# final_season_rank     float64       233              3218         0
# sg_tee_to_green       float64      2095              3218         0

# %% [markdown]
# Now, we have a clean dataset, where each column has the same number of total observations and no missing values.

# %%
PGA_clean.head(20)
# Out:
# col_id  year       player_name  sg_total  sg_off_the_tee  sg_approach  \
# 0       2007    Aaron Baddeley     1.064           0.152       -0.252
# 1       2007        Adam Scott     1.234           0.478        0.708
# 2       2007        Alex Cejka     0.728           0.257        0.609
# 3       2007     Anders Hansen    -0.089          -0.224        0.335
# 4       2007     Andrew Buckle    -0.265          -0.223       -0.280
# 5       2007       Anthony Kim     0.673           0.578        0.200
# 7       2007  Arron Oberholser     1.183           0.125        0.300
# 9       2007       Bart Bryant     0.638           0.180        0.253
# 12      2007        Ben Curtis    -0.749          -0.030       -0.554
# 14      2007         Bill Haas     0.408           0.443        0.063
# 15      2007     Billy Andrade    -0.241          -0.272        0.244
# 16      2007     Billy Mayfair     0.604           0.234        0.315
# 18      2007       Bo Van Pelt     0.949           0.354        0.282
# 20      2007         Bob Estes     0.380          -0.373       -0.094
# 21      2007        Bob Heintz     0.078          -0.267       -0.113
# 23      2007          Bob Tway    -0.329          -0.314       -0.131
# 24      2007       Boo Weekley     0.627           0.876        0.231
# 27      2007   Brandt Snedeker     0.672          -0.157        0.226
# 28      2007  Brendon de Jonge    -0.271          -0.002        0.079
# 30      2007     Brett Quigley     0.128          -0.248        0.362
#
# col_id  sg_around_green  sg_putting  driving_distance  driving_accuracy  \
# 0                 0.535       0.629             291.9             60.00
# 1                -0.081       0.129             300.9             59.17
# 2                 0.340      -0.479             288.9             68.08
# 3                -0.023      -0.176             280.7             66.95
# 4                 0.077       0.161             294.7             58.14
# 5                 0.016      -0.121             302.4             60.79
# 7                 0.396       0.362             285.5             61.70
# 9                 0.008       0.198             281.1             70.66
# 12                0.023      -0.188             277.1             67.37
# 14               -0.081      -0.018             302.7             62.93
# 15               -0.079      -0.134             286.2             59.56
# 16                0.141      -0.086             286.8             70.70
# 18                0.153       0.160             294.7             61.97
# 20                0.232       0.616             282.6             65.28
# 21                0.237       0.221             285.2             64.74
# 23               -0.044       0.160             284.3             60.45
# 24               -0.289      -0.192             296.6             64.65
# 27                0.092       0.511             285.6             59.80
# 28               -0.265      -0.083             293.8             59.20
# 30                0.020      -0.005             290.7             55.90
#
# col_id  greens_in_regulation  scoring_average  money_earned  \
# 0                      60.35           70.088     3441119.0
# 1                      65.44           70.008     3413185.0
# 2                      69.44           70.437      868303.0
# 3                      62.85           70.856      461216.0
# 4                      62.52           71.443      513630.0
# 5                      65.35           70.128     1545195.0
# 7                      62.25           69.807     1797458.0
# 9                      66.34           70.637     1167874.0
# 12                     60.56           71.582      772321.0
# 14                     65.98           70.653      967443.0
# 15                     65.03           71.588      499197.0
# 16                     68.08           70.444     1814518.0
# 18                     66.40           70.051     1559181.0
# 20                     63.19           70.962      878051.0
# 21                     63.17           71.162      649342.0
# 23                     63.52           71.272      456767.0
# 24                     65.86           70.303     2613211.0
# 27                     64.58           70.089     2836643.0
# 28                     64.35           71.413      447172.0
# 30                     62.11           71.212      717411.0
#
# col_id  final_season_rank  sg_tee_to_green
# 0                     9.0            0.435
# 1                    12.0            1.105
# 2                   129.0            1.206
# 3                   138.0            0.088
# 4                   141.0           -0.426
# 5                    44.0            0.794
# 7                    33.0            0.821
# 9                    80.0            0.441
# 12                  115.0           -0.561
# 14                  127.0            0.425
# 15                  137.0           -0.107
# 16                   51.0            0.690
# 18                   61.0            0.789
# 20                  108.0           -0.235
# 21                  117.0           -0.143
# 23                  143.0           -0.489
# 24                   22.0            0.818
# 27                   17.0            0.161
# 28                  175.0           -0.188
# 30                  114.0            0.134

# %%
PGA_clean_z.head()
# Out:
# col_id  year     player_name  sg_total  sg_off_the_tee  sg_approach  \
# 0       2007  Aaron Baddeley  1.270978        0.257487    -0.934173
# 1       2007      Adam Scott  1.526412        1.181114     1.685539
# 2       2007      Alex Cejka  0.766121        0.554974     1.415382
# 3       2007   Anders Hansen -0.461464       -0.807801     0.667672
# 4       2007   Andrew Buckle -0.725913       -0.804968    -1.010582
#
# col_id  sg_around_green  sg_putting  driving_distance  driving_accuracy  \
# 0              2.264203    1.724075         -0.169482         -0.344816
# 1             -0.484133    0.261055          0.735368         -0.507903
# 2              1.394194   -1.517978         -0.471099          1.242826
# 3             -0.225361   -0.631387         -1.295518          1.020792
# 4              0.220797    0.354688          0.112027         -0.710288
#
# col_id  greens_in_regulation  scoring_average  money_earned  \
# 0                  -2.128946        -1.128322     3441119.0
# 1                  -0.232152        -1.247124     3413185.0
# 2                   1.258452        -0.610048      868303.0
# 3                  -1.197318         0.012177      461216.0
# 4                  -1.320293         0.883886      513630.0
#
# col_id  final_season_rank  sg_tee_to_green  money_earned_log  \
# 0                     9.0         0.416555         15.051308
# 1                    12.0         1.506587         15.043157
# 2                   129.0         1.670906         13.674297
# 3                   138.0        -0.147984         13.041624
# 4                   141.0        -0.984218         13.149260
#
# col_id  money_earned_log_z
# 0                 1.096274
# 1                 1.087346
# 2                -0.411903
# 3                -1.104841
# 4                -0.986952
